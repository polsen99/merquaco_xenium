# %%
# %load_ext autoreload 
# %autoreload 2

from merquaco.experiment import XeniumExperiment
import os
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test_path = '../xenium_output/embryonic/output-XETG00210__0078407__1453118620__20250801__185316'
os.listdir(test_path)
# Out:
# ['experiment.xenium',
#  'gene_panel.json',
#  'analysis.zarr.zip',
#  'cells.csv.gz',
#  'cells.zarr.zip',
#  'cell_boundaries.csv.gz',
#  'metrics_summary.csv',
#  'aux_outputs',
#  'cell_feature_matrix.h5',
#  'transcripts.zarr.zip',
#  'transcripts.parquet',
#  '.end-of-run',
#  'cell_boundaries.parquet',
#  'nucleus_boundaries.parquet',
#  'analysis_summary.html',
#  'morphology.ome.tif',
#  'cells.parquet',
#  'cell_feature_matrix',
#  'analysis',
#  'cell_feature_matrix.zarr.zip',
#  'nucleus_boundaries.csv.gz',
#  'morphology_focus']

# %%
exp = XeniumExperiment(f'{test_path}/transcripts.parquet')
# Out:
# Processing transcripts dataframe
# renaming columns
# removing blanks
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 exp = XeniumExperiment(f'{test_path}/transcripts.parquet')
#
# File /allen/programs/celltypes/workgroups/rnaseqanalysis/mFISH/xenium_qc/merquaco/merquaco/experiment.py:755, in XeniumExperiment.__init__(self, transcripts_input, ilastik_program_path, dapi_high_res_image_path, output_dir, ventricle_genes_list, force_mask, fov_dimensions)
#     753 print('removing blanks')
#     754 filtered_transcripts = self.remove_low_quality_transcripts(self.transcripts)
# --> 755 self.filtered_transcripts = self.remove_controls(filtered_transcripts)
#     756 # Get basic experiment information
#     757 print('')
#
# File /allen/programs/celltypes/workgroups/rnaseqanalysis/mFISH/xenium_qc/merquaco/merquaco/experiment.py:840, in XeniumExperiment.remove_controls(transcripts, which)
#     837     raise KeyError(f'`which` parameter is invalid. must be one of {valid_which}')
#     839 if which == 'all':
# --> 840     filtered_transcripts = transcripts[~transcripts['gene'].str.startswith('NegControl',
#     841                                                                            'Unassigned',
#     842                                                                            'Deprecated')]
#     844 else:
#     845     filtered_transcripts = transcripts[~transcripts['gene'].str.startswith(which)]
#
# File /allen/programs/celltypes/workgroups/rnaseqanalysis/mFISH/paulolsen/miniconda3/envs/merquaco/lib/python3.12/site-packages/pandas/core/strings/accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# TypeError: StringMethods.startswith() takes from 2 to 3 positional arguments but 4 were given

# %%
exp
